# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"H:\MASAI\data set\New folder\csv for ML\kc_house_data.csv")

# %%
df

# %% [markdown]
# # 1.a.Check the top 10 and bottom 10 of the dataset.

# %%
df.head(10)

# %%
df.tail(10)

# %% [markdown]
# # 1.b Check for null values.

# %%
df.isnull().sum()

# %% [markdown]
# # 1. c. Check the statistical summary and info of the data.

# %%
df.describe()

# %%
df.info()

# %% [markdown]
# # 1.d. Handle the null and noise values.

# %%
# NULL

# %%
df.isnull().sum()

# %% [markdown]
# ## NOISE

# %%
for i in df.columns:
    print(i,df[i].unique(),"\n")
# Out:
# id [7129300520 6414100192 5631500400 ... 1523300141  291310100 1523300157]
#
# date ['10/13/2014' '12-09-2014' '2/25/2015' '2/18/2015' '05-12-2014'
#  '6/27/2014' '1/15/2015' '4/15/2015' '03-12-2015' '04-03-2015' '5/27/2014'
#  '5/28/2014' '10-07-2014' '1/24/2015' '7/31/2014' '5/29/2014' '12-05-2014'
#  '4/24/2015' '5/14/2014' '8/26/2014' '07-03-2014' '5/16/2014' '11/20/2014'
#  '11-03-2014' '6/26/2014' '12-01-2014' '6/24/2014' '03-02-2015'
#  '11-10-2014' '12-03-2014' '6/13/2014' '12/30/2014' '2/13/2015'
#  '6/20/2014' '7/15/2014' '08-11-2014' '07-07-2014' '10/28/2014'
#  '7/29/2014' '7/18/2014' '3/25/2015' '7/16/2014' '4/28/2015' '03-11-2015'
#  '9/16/2014' '2/17/2015' '12/31/2014' '02-05-2015' '03-03-2015'
#  '8/19/2014' '04-07-2015' '8/27/2014' '2/23/2015' '12-10-2014' '8/28/2014'
#  '10/21/2014' '12-07-2014' '06-03-2014' '09-09-2014' '10-09-2014'
#  '8/25/2014' '06-12-2014' '09-12-2014' '01-05-2015' '06-10-2014'
#  '07-10-2014' '3/16/2015' '11-05-2014' '4/20/2015' '06-09-2014'
# ...

# %%
df
# Out:
#                id        date          price  bedrooms bathrooms sqft_living  \
# 0      7129300520  10/13/2014  ? 2,21,900.00         3         1        1180
# 1      6414100192  12-09-2014  ? 5,38,000.00         3      2.25        2570
# 2      5631500400   2/25/2015  ? 1,80,000.00         2         1         770
# 3      2487200875  12-09-2014  ? 6,04,000.00         4         3        1960
# 4      1954400510   2/18/2015  ? 5,10,000.00         3         2        1680
# ...           ...         ...            ...       ...       ...         ...
# 21592   263000018   5/21/2014  ? 3,60,000.00         3       2.5        1530
# 21593  6600060120   2/23/2015  ? 4,00,000.00         4       2.5        2310
# 21594  1523300141   6/23/2014  ? 4,02,101.00         2      0.75        1020
# 21595   291310100   1/16/2015  ? 4,00,000.00         3       2.5        1600
# 21596  1523300157  10/15/2014  ? 3,25,000.00         2      0.75        1020
#
# ...

# %%
df['price'].unique()
# Out:
# array(['? 2,21,900.00', '? 5,38,000.00', '? 1,80,000.00', ...,
#        '? 5,41,800.00', '? 6,10,685.00', '? 4,02,101.00'], dtype=object)

# %%
df['price'] = df['price'].str.replace("?",'',)
# Out:
# C:\Users\shreyash\AppData\Local\Temp\ipykernel_4612\817200740.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['price'] = df['price'].str.replace("?",'',)

# %%
df['price'] = df['price'].str.replace(",",'',)

# %%
df['price'] = pd.to_numeric(df['price'], errors = 'coerce')

# %%
df.drop(df[(df['bathrooms'] == '-')| (df["bathrooms"] == '&')].index,inplace=True)

# %%
df['bathrooms'] = pd.to_numeric(df['bathrooms'], errors = 'coerce')

# %%
df['bathrooms'].dtypes
# Out:
# dtype('float64')

# %%
df['sqft_living'] = pd.to_numeric(df['sqft_living'], errors='coerce')

# %%
df['sqft_lot'] = pd.to_numeric(df['sqft_lot'], errors='coerce')

# %%
df['waterfront'].unique()
# Out:
# array(['0', '1', '&'], dtype=object)

# %%
df.drop(df[(df['waterfront'] == '&')].index,inplace=True)

# %%
df['waterfront'] = pd.to_numeric(df['waterfront'], errors='coerce')

# %%
df['view'].unique()
# Out:
# array(['0', '3', '4', '2', '1', '&', '%'], dtype=object)

# %%
df.drop(df[(df['view'] == '&')| (df['view'] == '%')].index, inplace=True)

# %%
df['view'] = pd.to_numeric(df['view'], errors='coerce')

# %%
df['view'].unique()
# Out:
# array([0, 3, 4, 2, 1], dtype=int64)

# %%
df['condition'].unique()
# Out:
# array(['3', '5', '4', '1', '2', '-'], dtype=object)

# %%
df.drop(df[(df['condition'] == '-')].index,inplace=True)

# %%
df['condition'] = pd.to_numeric(df['condition'], errors='coerce')

# %%
df['grade'].unique()
# Out:
# array(['7', '6', '8', '11', '9', '5', '10', '12', '4', '&', '3', '13',
#        '%'], dtype=object)

# %%
df.drop(df[(df['grade'] == '%')].index,inplace=True)

# %%
df['grade'] = pd.to_numeric(df['grade'], errors='coerce')

# %%
df['sqft_above'] = pd.to_numeric(df['sqft_above'], errors='coerce')

# %%
df.drop(df[(df['yr_built'] == '-')| (df['yr_built'] == '&')].index, inplace=True)

# %%
df['yr_built'] = pd.to_numeric(df['yr_built'], errors='coerce')

# %%
df.drop(df[(df['yr_renovated'] == '&') | (df['yr_renovated'] == '%')].index, inplace=True)

# %%
df['yr_renovated'] = pd.to_numeric(df['yr_renovated'], errors='coerce')

# %%
df['lat'] = pd.to_numeric(df['lat'], errors='coerce')

# %%
df['long'] = pd.to_numeric(df['long'], errors='coerce')

# %% [markdown]
# # 1. e. Datatype

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living      float64
# sqft_lot         float64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade            float64
# sqft_above       float64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# # 2 .a. Data cleaning.
# Remove special characters or strings from the numerical value.

# %%
df['price']
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21592    360000.0
# 21593    400000.0
# 21594    402101.0
# 21595    400000.0
# 21596    325000.0
# Name: price, Length: 21583, dtype: float64

# %% [markdown]
# # All Cleaning already done above

# %%
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00       1180.0
# 1      6414100192  12-09-2014  538000.0         3       2.25       2570.0
# 2      5631500400   2/25/2015  180000.0         2       1.00        770.0
# 3      2487200875  12-09-2014  604000.0         4       3.00       1960.0
# 4      1954400510   2/18/2015  510000.0         3       2.00       1680.0
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50       1530.0
# 21593  6600060120   2/23/2015  400000.0         4       2.50       2310.0
# 21594  1523300141   6/23/2014  402101.0         2       0.75       1020.0
# 21595   291310100   1/16/2015  400000.0         3       2.50       1600.0
# 21596  1523300157  10/15/2014  325000.0         2       0.75       1020.0
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# # 2. b . Converting the data to its respective format(type).

# %%
# Done above in Q 1.

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living      float64
# sqft_lot         float64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade            float64
# sqft_above       float64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# # 3. Handle the Outliers.

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
col = ['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']

# %%
for i in col:
    percentile25 = df[i].quantile(0.25)
    percentile75 = df[i].quantile(0.75)
    IQR = percentile75 - percentile25
    Upperlimit = percentile75 + 1.5*IQR
    Lowerlimit = percentile25 - 1.5*IQR
    df= df[df[i]<=Upperlimit]
    df = df[df[i]>=Lowerlimit]
    plt.figure()
    sns.boxplot(y=i, data =df)

# %% [markdown]
# # 4 . Use any scaling type for feature scaling.

# %%
df.corr()
# Out:
# C:\Users\shreyash\AppData\Local\Temp\ipykernel_4612\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000  0.031594 -0.003845   0.028078     0.025234 -0.049577
# price          0.031594  1.000000  0.209839   0.315028     0.490590 -0.106160
# bedrooms      -0.003845  0.209839  1.000000   0.426687     0.604853  0.209594
# bathrooms      0.028078  0.315028  0.426687   1.000000     0.666315 -0.103894
# sqft_living    0.025234  0.490590  0.604853   0.666315     1.000000  0.158418
# sqft_lot      -0.049577 -0.106160  0.209594  -0.103894     0.158418  1.000000
# floors         0.018984  0.212723  0.118461   0.520793     0.304488 -0.441447
# ...

# %%
df.drop(df[['id','waterfront','view','date','yr_built','yr_renovated','zipcode','long','sqft_lot15','sqft_lot']], axis =1, inplace = True)

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  floors  condition  grade  \
# 0      221900.0         3       1.00       1180.0     1.0          3    7.0
# 2      180000.0         2       1.00        770.0     1.0          3    6.0
# 3      604000.0         4       3.00       1960.0     1.0          5    7.0
# 4      510000.0         3       2.00       1680.0     1.0          3    8.0
# 6      257500.0         3       2.25       1715.0     2.0          3    7.0
# ...         ...       ...        ...          ...     ...        ...    ...
# 21592  360000.0         3       2.50       1530.0     3.0          3    8.0
# 21593  400000.0         4       2.50       2310.0     2.0          3    8.0
# 21594  402101.0         2       0.75       1020.0     2.0          3    7.0
# 21595  400000.0         3       2.50       1600.0     2.0          3    8.0
# 21596  325000.0         2       0.75       1020.0     2.0          3    7.0
#
#        sqft_above  sqft_basement      lat  sqft_living15
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'floors', 'condition',
#        'grade', 'sqft_above', 'sqft_basement', 'lat', 'sqft_living15'],
#       dtype='object')

# %%
col = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'floors', 'condition',
       'grade', 'sqft_above', 'sqft_basement', 'lat', 'sqft_living15']

# %%
x = df[['bedrooms', 'bathrooms', 'sqft_living', 'floors', 'condition',
       'grade', 'sqft_above', 'sqft_basement', 'lat', 'sqft_living15']].values

# %%
y= df['price'].values

# %% [markdown]
# # 5 . Split into test train

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train, y_test = train_test_split(x,y,test_size=0.2, random_state =43)

# %% [markdown]
# # 4 Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
x_test =sc.transform(x_test)

# %% [markdown]
# # 6.  Create and train

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

reg.fit(x_train,y_train)

y_pred = reg.predict(x_test)

# %%
y_pred1= reg.predict(x_train)

# %% [markdown]
# # 7 .Get the prediction of the model for both training and testing data.

# %%
# for testing data

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.571566479464733

# %%
# for training data

# %%
r2_score(y_train, y_pred1)
# Out:
# 0.5616431237887247

# %% [markdown]
# # 8. Get the accuracy of the model with the help of different metrics.

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_train,y_pred1)
# Out:
# 16087274869.62792

# %%
# RMS

# %%
np.sqrt(mean_squared_error(y_train,y_pred1))
# Out:
# 126835.62145402182
